# %% [markdown]
# # USE https://docs.python.org/3/tutorial/datastructures.html#

# %%
## SETS HUMMM Are weird
a = (1,2,3)
print(type(a))
#b = set(1,2,3)
b = set('1,2,3')
print(type(b))
basket = {'apple', 'orange', 'apple', 'pear', 'orange', 'banana'}
c = set('abracadabra')

# unordered
for i in b:
    print(i)

for l in c:
    print(c)
# Out:
# <class 'tuple'>
# <class 'set'>
# 1
# 3
# ,
# 2
# {'b', 'c', 'a', 'r', 'd'}
# {'b', 'c', 'a', 'r', 'd'}
# {'b', 'c', 'a', 'r', 'd'}
# {'b', 'c', 'a', 'r', 'd'}
# {'b', 'c', 'a', 'r', 'd'}

# %%
#
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(f'fruits: {fruits}')
print(type(fruits))
print(fruits.count('apple'))

print(fruits.count('tangerine'))

print(fruits.index('banana'))

print(fruits.index('banana', 4)) # Find next banana starting at position 4

fruits.reverse()
print(f'reversed: {fruits}')

fruits.append('grape')
print(f'with grapes: {fruits}')

fruits.sort()
print(f'sorted: {fruits}')

fruits.pop()
print(f'smaller: {fruits}')
# Out:
# fruits: ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
# <class 'list'>
# 2
# 0
# 3
# 6
# reversed: ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']
# with grapes: ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'grape']
# sorted: ['apple', 'apple', 'banana', 'banana', 'grape', 'kiwi', 'orange', 'pear']
# smaller: ['apple', 'apple', 'banana', 'banana', 'grape', 'kiwi', 'orange']

# %%
squares = [x**2 for x in range(10)]
print(f'{squares} is type: {type(squares)}')
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81] is type: <class 'list'>
# <generator object <genexpr> at 0x7efdf6f79e00> is type: <class 'generator'>

# %%
anotherlamb = lambda x:x+1, range(10)
print(f'anotherlamb: {anotherlamb}')
for n in anotherlamb:
    print(n)
# Out:
# (<function <lambda> at 0x7efe10514280>, range(0, 10))
