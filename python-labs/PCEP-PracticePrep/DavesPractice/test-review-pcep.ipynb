# %% [markdown]
# ### TEST REVIEW Excersize
# These excersizes are either items missed in jupyter notebooks or areas need more practice

# %%
# flow division
a = 5
b = 3
c = 1
print(c //a)
print(b //a)
print(a //b)
print(b //b)
print(b-c //a)
print(3-c //a)
# Out:
# 0
# 0
# 1
# 1
# 3
# 3

# %%
# flow division
a = 5.2
b = 3.0
c = 1.0
print(a //b)
print(b //b)
print(b //a)
print(b-c//a)
# Out:
# 1.0
# 1.0
# 0.0
# 3.0

# %%
# flow division

print(9//2)
print(9//3)
print(8//3)
print(6//3)
print(5//3)
print(4//3)
print(3//3)
# Out:
# 4
# 3
# 2
# 2
# 1
# 1
# 1

# %%
lst = [1, 5, 10, 15, 20]
print(lst[::-1])

# %%
def swap(num1, num2):
   temp = num1;
   num1 = num2;
   num2 = temp;
num1 = (2)
num2 = (5)
swap(num1, num2)
print(num1 , num2)

# %%
print(5** 2 ** 0 ** 1)
The exponentiation operator uses right-sided binding, e.g., 2 ** 2 ** 3 = 256. Hence,it is 5** 2 ** 0 ** 1 = 5
# Out:
# 5

# %%
dict = {'r':2,'p':4,'q':5}
print(sorted(dict))
# Out:
# ['p', 'q', 'r']

# %%
# SEEE BLOAK ALIGNMENT
french_greeting = 'Bonjour'
for i in french_greeting:
  if i == 'o':
     continue
  print(i)
else:
  print('Madam')

# %%
z = 0
y = 10
x = y < z and z > y or y > z and z < y

# %%
ERRORS NEED ERRORS BACK

# %%
print(len(0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(len(0))
#
# TypeError: object of type 'int' has no len()

# %%
mystr = input("enter 0")
print(len(mystr))
print(int(mystr)/len(mystr))
# Out:
# enter 0 0
# 1
# 0.0

# %%
does dict have a len function

# %%
dct = {'one':'two', 'three':'one','two': 'three'}
v = dct['three']
for k in range(len(dct)):
    v = dct[v]
    print(v)

# same as
print(v)
print(dct['three'])
# Out:
# two
# three
# one
# one
# one

# %%
mytuple = (1,2,3)
print(type(mytuple))
mytuple[1] = mytuple[1] + mytuple[0]
print(mytuple)
# Out:
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 mytuple = (1,2,3)
#       2 print(type(mytuple))
# ----> 3 mytuple[1] = mytuple[1] + mytuple[0]
#       4 print(mytuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
lst = [i for i in range(-1, -2)]
print(lst)
# Out:
# []

# %%
dd = {"1": "0", "0":"1"}
for x in dd.vals():
    print(x, end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 dd = {"1": "0", "0":"1"}
# ----> 2 for x in dd.vals():
#       3     print(x, end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %%
dd = {"1": "0", "0":"1"}
for x in dd.values():
    print(x, end="")
# Out:
# 01

# %%
foo = (1,2,3)
foo.index(0)
print(index(0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 foo = (1,2,3)
# ----> 2 foo.index(0)
#       3 print(index(0))
#
# ValueError: tuple.index(x): x not in tuple

# %%
try:
    print(5/0)
    break
except:
    print("sorry")
except (ValueError, ZeroDivisionError):
    print("Too badd....")
# Out:
#   Cell In[16], line 3
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
a = 1
b = 0
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)
# Out:
# 0 1

# %%
my_list = [1,2]
for v in range(2):
    my_list.insert(-1, my_list[v])
print(my_list)
# Out:
# [1, 1, 1, 2]

# %%
dct = {}
dct['1'] = (1,2)
dct['2'] = (2,1)

print(f'dct: {dct}')

for x in dct.keys():
    print(f'x: {x}')
    print(dct[x][1], end="")
# Out:
# dct: {'1': (1, 2), '2': (2, 1)}
# x: 1
# 2x: 2
# 1

# %%
my_list = [x for x in range(5)]

def fun(lst):
    del lst[lst[2]]
    return lst

print(my_list)
print(fun(my_list))
print(fun(fun(my_list)))
# Out:
# [0, 1, 2, 3, 4]
# [0, 1, 3, 4]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 9
#       7 print(my_list)
#       8 print(fun(my_list))
# ----> 9 print(fun(fun(my_list)))
#
# Cell In[27], line 4, in fun(lst)
#       3 def fun(lst):
# ----> 4     del lst[lst[2]]
#       5     return lst
#
# IndexError: list assignment index out of range
