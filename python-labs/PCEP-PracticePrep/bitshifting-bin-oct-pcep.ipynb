# %% [markdown]
# # CPEP Practice Test 2

# %% [markdown]
# ### PCEP bit shifting

# %% [markdown]
# #### Bitwise & and
# Everthing is 0 except 1&1
# #### Bitwise | or
# everything is 1 except 0|0
# #### Bitwise xor ^
# Doubles (0^0, 1^1) are 0.  1^0 is a 1.

# %% [markdown]
# #### Bitwise | or
# Everything is 1 except 0|0.  Oposite of &
# print(0|0, 0|1, 0|0, 1|1)

# %%
#### Bitwise | or
# print(f'1|0 = {1|0}')
# print(f'1|1 = {1|1}')
# print(f'0|0 = {0|0}')
#print(0|0, 0|1, 0|0, 1|1)

# %%
a = 1 == 1&1
b = 1 == 0^1
c = 1 == 0|1

# print(a)
# print(b)
# print(c)

# %% [markdown]
# #### Bitwise & and
# Everything is 0 except 1|1.  Oposite of |
# print(0|0, 0|1, 0|0, 1|1)

# %%
#### Bitwise & and 
# print(f'1&0 = {1&0}')
# print(f'0&0 = {0&0}')
# print(f'1&1 = {1&1}')

# %% [markdown]
# #### Bitwise ^ xor
# Everything is a 0 except 1 ^ 0
# Doubles are 0.  1 ^ 0 = 1

# %%
#### Bitwise ^ xor
# print(f'1^1 = {1^1}')
# print(f'0^0 = {0^0}')
# print(f'1^0 = {1^0}')
#print(0^0, 0^1, 1^1)

# %% [markdown]
# #### Fill in right value for a.
# #### Pay attention to oporator in print funtion

# %%
## & Addition
x = 0b10011100
y = 0b00110100 
#a = 0b0010100
# print(a == (y&x))
# print(a) 
# print(y&x)

# %%
## Or | Addition
x = 0b10011100
y = 0b00110100 
#a = 0b
# print(a == (y|x))
# print(a) 
# print(y&x)

# %%
## Regular Addition
x = 0b10011100
y = 0b00110100 
#a = 0b?
# print(a == (y^x))
# print(a) 
# print(y^x)

# %%
## Regular Addition
x = 0b10011100
y = 0b00110100 
# a = 0b?
# print(a == (y^x))
# print(a) 
# print(y&x)

# %%
## Regular Addition
x = 0b10011100
y = 0b00110100 
# a = 0b
# print(a == (y^x))
# print(a) 
# print(y^x)

# %%
## Regular Addition
## Follow rule
x = 0b10111100
y = 0b10110101 
# a = 0b?
# print(a == y&x)
# print(a)
# print(y&x)
# Out:
# True
# 180
# 180

# %%
## Regular Addition
## Follow rule
x = 0b10111100
y = 0b10110101 
# a = 0b?
# print(a)
# print(y^x)
# print(a == (y^x))

# %%
## Regular Addition
## Follow rule
x = 0b10111100
y = 0b10110101 
# a = 0b
# print(a)
# print(y|x)
# print(a == y|x)

# %%
## Regular Addition
## Follow rule
x = 0b10111100
y = 0b10110101 
# a = 0b?
# print(a)
# print(y&x)
# print(a == y&x)

# %%
## Regular Addition ## Follow rule
x = 0b10011100
y = 0b10110101 
# a = 0b?
# print(a == y&x)
# print(a)
# print(y&x)

# %%
## Regular Addition
x = 0b00111100
y = 0b10110100 
# a = 0b?
# print(a == y|x)
# print(a)
# print(y|x)
# print(bin(a))

# %% [markdown]
# #### Bitwise | or
# Everything is 1 except 0|0.  Oposite of &
# print(0|0, 0|1, 0|0, 1|1)

# %%
## Regular Addition
## What happens when these are anded (|)  
## Follow rule
x = 0b10011100
y = 0b10110100 
# a = 0b?
# print(a)
# print(y|x)
# print(bin(a))
# print(a == (y|x))

# %%
## Regular Addition
## What happens when these are anded (|)  
## Follow rule
x = 0b10011100
y = 0b10010101 
# a = 0b?
# print(a == (y|x))
# print(a)
# print(y|x)
# print(bin(a))

# %%
print(f'1|0 = {1|0}')
print(f'1|1 = {1|1}')
print(f'0|0 = {0|0}')
# Out:
# 1|0 = 1
# 1|1 = 1
# 0|0 = 0

# %%
x = 0b10011101
y = 0b10110101 
a = 0b00101000
answer = bin(x^y)
print(f'bin(x&y) should equal a')
print(f'{bin(x&y)} should equal {bin(a)} {bin(a) == answer}')
# Out:
# bin(x&y) should equal a
# 0b10010101 should equal 0b101000 True

# %% [markdown]
# #### Bitwise ^ xor
# kind of weird
# Everything is 0 except 1^0.
# print(0^0, 0^1, 0^0, 1^1)

# %%
print(0^0, 0^1,  1^1)
# Out:
# 0 1 0

# %%
print(f'1^0 = {1^0}')
print(f'1^1 = {1^1}')
print(f'0^0 = {0^0}')
# Out:
# 1^0 = 1
# 1^1 = 0
# 0^0 = 0

# %%
x = 0b10000000
y = 0b10110101 
a = 0b00110101
answer = bin(x^y)
print(f'bin(x&y) should equal bin{a}')
print(f'{bin(x&y)} should equal {bin(a)} {bin(a) == answer}')
# Out:
# bin(x&y) should equal bin53
# 0b10000000 should equal 0b110101 True
