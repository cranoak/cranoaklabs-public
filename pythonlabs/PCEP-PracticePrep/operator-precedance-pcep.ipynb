# %% [markdown]
# # Operator Precedence
# [Operator Precedence](https://www.geeksforgeeks.org/precedence-and-associativity-of-operators-in-python/)
# P means parentheses
# E means exponent
# M means multiplication
# D means division
# A means addition
# S means Subtraction
# ### Follow the rules to predict output

# %%
res = str(bool(1) + float(12) / float(2))
print(res)

# %%
res = str(bool(1) + float(12) / float(2))
print(res)                                  # 7.0
print(str(bool(1) + float(12) / float(2)))  # 7.0
print(str(True + 12.0 / 2.0))               # 7.0
print(str(True + (12.0 / 2.0)))             # 7.0
print(str(True + 6.0))                      # 7.0
print(str(1 + 6.0))                         # 7.0
print(str(7.0))                             # 7.0
print('7.0')                                # 7.0

# %%
# Floor Division.  Ever/ything but the remainder
# print(f'45/4 = {45/4}')
# print(f'45//4 = {45//4}')
# print(f'45%4 = {45%4}')

# %%
# Floor Division.  Ever/ything but the remainder
# numerator = 45
# denominator = 4
# remainder = 45%4
# base = 45//4

# print(f'{numerator}/{denominator} = {numerator/denominator}') 
# print(f'{numerator}//{denominator} = {numerator//denominator}') 
# print(f'45%4 = {45%4}')
# print(f'base + remainder/denominator: {base + (remainder/denominator)}')

# %%
a = 2
b = 3
# print(b**a)
# print(b*a)
# print(b-a)
# print(b+a)
# print(b//a)

# %%
a = 3
b = 2
# print(b**a)
# print(b*a)
# print(b-a)
# print(b+a)
# print(b//a)

# %%
a = 3
b = 2
b += a
print(b)
# print(b**a)
# print(b*a)
# print(b//a)

# %%
num=3**2*2
#print(num)

# %%
num = (2**2*2/2+2)
# what is num
# print(num)

# %%
num = (2**2*2/2+2-2)
# what is num
# print(num)

# %%
# enter hi and hello
a = input()
b = input()

### Guess answer
## Comment and run
# print(a + b)
# print(a + b * 2)
# print((a + b) * 2)

# %% [markdown]
# P means parentheses
# E means exponent
# M means multiplication
# D means division
# A means addition
# S means Subtraction

# %% [markdown]
# #### Fix the code

# %%
# enter numerical values for a and b
# fix the code
## WHAT IS ANSWER IF a= 2 and b = 3
# Copy code and fix the copy so integers work
# Fix code to handle integers as input
print("Notice Values are what is expected")
a = input()
b = input()
 
# print(a + b)
# print(a + b * 2)
# print((a + b) * 2)
# Out:
# Notice Values are what is expected

# %%
num = (2**2*2/2+2**2)
# what is num
# print(num)

# %%
num = (3**2*4/2)
# what is num
# print(num)

# %%
num = (3**2*4//2)
# what is num
# print(num)
# print(type(num))

# %%
num = (3**2*4/2)
# what is num
# print(num)
# print(type(num))

# %% [markdown]
# Now with 3's

# %% [markdown]
# Which are floats?

# %%
print(3**3//3)
print(27//3)
print(3*3**3/3)
print(3-3+3/3)
print(3-3//2/1)
print(3-3+3/3//3)

# %% [markdown]
# Notice suttle type change

# %%
x=3+3/3
y=3+1
print(f'x has type: {type(x)}')
print(f'y has type: {type(y)}')

# %% [markdown]
# #### +x, -x, ~x operators

# %%
x =  ~2
y = 1 % 2 

print(x) 
print(y)

# %%
x =  ~4
y = 4 % 2 

print(x) 
print(y)

# %%
x =  ~4
y = 4 % 2 
z = ~x
print(x) 
print(y)
print(z)

# %%
x = 1 ~ 2 + 3 // 3 + 4 ** 2
y = 1 / 2 + (3 // 3) + 4 ** 2

# print(x)                          # 17.5
# print(y)                          # 17.5

# %%
x = 1 / 2 + 3 // 3 + 4 ** 2
y = 1 / 2 + (3 // 3) + (4 ** 2)

# print(x)                          # 17.5
# print(y)                          # 17.5

# %% [markdown]
# P means parentheses
# E means exponent
# M means multiplication
# D means division
# A means addition
# S means Subtraction
#
# Link: [Operator Precedence](https://www.geeksforgeeks.org/precedence-and-associativity-of-operators-in-python/)
# Let us look at some Python coding examples with some inferences.

# %% [markdown]
# Notice which produces a float

# %%
x=5/7
y=5//7
print(x)
print(y)

print(f'x is type: {type(x)}')
print(f'y is type: {type(y)}')

# %% [markdown]
# Short Circuiting

# %%
print("a") if print("b") else print("c")
# Here the boolean value of print(“b”) is False. So after executing print(“b”), print (“c”) is executed, skipping print(“a”).

# %% [markdown]
# Q1. Are 4+3*2//3 same as (4+3)*2//3. Show using Python coding.
#
# Ans 1. No. They are not the same. The below coding block shows this.

# %%
x=4+3*2//3
y=(4+3)*2//3
# print(x)
# print(y)
# print(3*2//3)
# print(x**y//x)

# %%
print("fix code below")
i = input(' Enter a number: ')
print(i - 4)

# %%
a = 2
b = 1
print(f'a: {a},b: {b}')
m  = a*(b+2) 
n = 2*3
o  = a*(b+2) 
print(f'm is: {m}')
print(f'n is: {n}')
print(f'o is: {o}')

# %%
a = 2
b = 1
print(f'a: {a},b: {b}')
a *= b + 2
print(f'a has new value: {a},b: {b}')

# %%
a = 4
b = 2
print(f'a: {a},b: {b}')
a *= b + a
print(4 * 6 )
print(f'a: {a},b: {b}')

# %% [markdown]
# #### Fix Code

# %%
c *= 4 + 2
print(f'c: {c}')

# %%
a = 2
b = 4
a += b + 2
#print(a)

# %%
a = 2
b = 4
a += b / 2
#print(a)

# %%
z = 3
y = 7
x = y < z and z > y or y > z and z < y
#x
