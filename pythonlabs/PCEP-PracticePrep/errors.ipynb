# %%
# PCEP ERRORS

# %%
print(True)
print(False)
print(f'int(True) is {int(True)}')
print(f'int(Fasle) is {int(False)}')
# Out:
# True
# False
# int(True) is 1
# int(Fasle) is 0

# %%
import math

def ave(x,y):
  z = ""
  try:
    #x = float(input("What number do you want to square?  "))
    x = float(x)
    y = int(y)
    try:
      z = x/y
      print(f'x is {x} and y is {y} so x/y is: {x/y}')
    except ZeroDivisionError:
      print("You need to take atleast one test")
  except ValueError:
    print("please enter a number")
  return z

#x = int(input("What number do you want to square?  "))
x = input("What is you total grades? ")
y = input("How many tests did you take? " )
answer = ave(x,y)
print(answer)

# %%
import math

def ave(x,y):
  z = ""
  try:
    #x = float(input("What number do you want to square?  "))
    x = float(x)
    y = int(y)
    try:
      z = x/y
      print(f'x is {x} and y is {y} so x/y is: {x/y}')
    except ZeroDivisionError:
      print("You need to take atleast one test")
  except ValueError:
    print("please enter a number")
  return z

#x = int(input("What number do you want to square?  "))

def grades():
    x = floatinput("What is you total grades? ")
    y = input("How many tests did you take? " )
x = floatinput("What is you total grades? ")
y = input("How many tests did you take? " )
answer = ave(x,y)
print(answer)
